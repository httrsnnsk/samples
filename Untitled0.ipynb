# %% [markdown]
# <a href="https://colab.research.google.com/github/httrsnnsk/samples/blob/master/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !ls /usr/lib/x86_64-linux-gnu/libcuda*
# !ls /usr/lib64-nvidia
# Out:
# /usr/lib/x86_64-linux-gnu/libcuda.so
# /usr/lib/x86_64-linux-gnu/libcuda.so.1
# /usr/lib/x86_64-linux-gnu/libcuda.so.396.54
# libcuda.so		       libnvidia-egl-wayland.so.1
# libcuda.so.1		       libnvidia-egl-wayland.so.1.0.3
# libcuda.so.396.44	       libnvidia-encode.so
# libEGL_nvidia.so.0	       libnvidia-encode.so.1
# libEGL_nvidia.so.396.44        libnvidia-encode.so.396.44
# libEGL.so		       libnvidia-fatbinaryloader.so.396.44
# libEGL.so.1		       libnvidia-fbc.so
# libEGL.so.1.1.0		       libnvidia-fbc.so.1
# libGLdispatch.so.0	       libnvidia-fbc.so.396.44
# libGLESv1_CM_nvidia.so.1       libnvidia-glcore.so.396.44
# libGLESv1_CM_nvidia.so.396.44  libnvidia-glsi.so.396.44
# libGLESv1_CM.so		       libnvidia-glvkspirv.so.396.44
# libGLESv1_CM.so.1	       libnvidia-gtk2.so.396.44
# libGLESv1_CM.so.1.2.0	       libnvidia-gtk3.so.396.44
# libGLESv2_nvidia.so.2	       libnvidia-ifr.so
# libGLESv2_nvidia.so.396.44     libnvidia-ifr.so.1
# ...

# %%
# !pip3 install http://download.pytorch.org/whl/cu92/torch-0.4.1-cp36-cp36m-linux_x86_64.whl
# !pip3 install torchvision
# Out:
# ...
#     100% |████████████████████████████████| 512.6MB 45.0MB/s
# tcmalloc: large alloc 1073750016 bytes == 0x58460000 @  0x7f05cdf7d2a4 0x594e17 0x626104 0x51190a 0x4f5277 0x510c78 0x5119bd 0x4f5277 0x4f3338 0x510fb0 0x5119bd 0x4f5277 0x4f3338 0x510fb0 0x5119bd 0x4f5277 0x4f3338 0x510fb0 0x5119bd 0x4f6070 0x510c78 0x5119bd 0x4f5277 0x4f3338 0x510fb0 0x5119bd 0x4f6070 0x4f3338 0x510fb0 0x5119bd 0x4f6070
# ...
#   Found existing installation: torch 0.3.0.post4
#     Uninstalling torch-0.3.0.post4:
#       Successfully uninstalled torch-0.3.0.post4
# ...

# %%
# %run main.py --dataset cifar10 --dataroot . --cuda
# Out:
# Namespace(batchSize=64, beta1=0.5, cuda=True, dataroot='.', dataset='cifar10', imageSize=64, lr=0.0002, manualSeed=None, ndf=64, netD='', netG='', ngf=64, ngpu=1, niter=25, nz=100, outf='.', workers=2)
# Random Seed:  4373
# Files already downloaded and verified
# Generator(
#   (main): Sequential(
#     (0): ConvTranspose2d(100, 512, kernel_size=(4, 4), stride=(1, 1), bias=False)
#     (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace)
#     (3): ConvTranspose2d(512, 256, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (4): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (5): ReLU(inplace)
#     (6): ConvTranspose2d(256, 128, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (7): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (8): ReLU(inplace)
# ...
